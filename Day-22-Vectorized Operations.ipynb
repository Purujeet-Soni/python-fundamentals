# %%
import numpy as np

# %%
arr = np.array([10, 20, 30])

# %%
Addition = arr+1000

print(Addition)
# Out:
# [1010 1020 1030]

# %%
Subtraction = arr - 5

print(Subtraction)
# Out:
# [ 5 15 25]

# %%
Multiplication = arr * 2

print(Multiplication)
# Out:
# [20 40 60]

# %%
Division = arr / 2

print(Division)
# Out:
# [ 5. 10. 15.]

# %%
Comparision = arr > 14

print(Comparision)
# Out:
# [False  True  True]

# %%
Sum = arr.sum()

print(Sum)
# Out:
# 60

# %%
Mean = arr.mean()

print(Mean)
# Out:
# 20.0

# %%
arr1 = [90, 20, 15]

Arr_Addition = arr + arr1 # Must Have Same Shape 

print(Arr_Addition)
# Out:
# [100  40  45]
