# %% [markdown]
# # Variable

# %%
# Valid Variable Name
name = "Abc"
_name = "Abc"
no = 1
NO = 1
no1 = 1

# Invalid Variable Name
# employee name  = "Abc"  (Space between Them) 
# 1no = 1                 (Number First)
# class = 5               (Reserve word)
# print = 1               (keyword) 
# $ = 1                   (Special Symbol)

# %% [markdown]
# # Data Types

# %%
a = 10              # int
b = 3.14            # float
c = 2 + 3j          # complex
d = "data science"  # str
e = True            # bool
f = [1, 2, 3]       # list
g = (4, 5, 6)       # tuple
h = {7, 8, 9}       # set
i = {"key": "value"}# dict
j = None            # NoneType
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
print(type(i))
print(type(j))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'bool'>
# <class 'list'>
# <class 'tuple'>
# <class 'set'>
# <class 'dict'>
# <class 'NoneType'>
