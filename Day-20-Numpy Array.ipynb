# %%
# Array Creation

# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
c = np.array([[[1, 2], [3, 4]], [[5,6], [6,7]]])

# %%
c
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [6, 7]]])

# %%
d = np.array(1)

# %%
d
# Out:
# array(1)

# %%
print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)

# Numpy Dimension
np.ndim(c)
# Out:
# 1
# 2
# 3
# 0
# 3

# %%
a = np.array([1, '2', 3])
a
# Out:
# array(['1', '2', '3'], dtype='<U11')

# %%
a = np.array([1, True, False])
a
# Out:
# array([1, 1, 0])

# %%
a = np.array([True, False, 0])
a
# Out:
# array([1, 0, 0])

# %%
a = np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
a = np.array([1.1, 1, 3])
a
# Out:
# array([1.1, 1. , 3. ])

# %%
a = np.array([1,1,1])
a
# Out:
# array([1, 1, 1])
